# %%
import statsmodels
import statsmodels.api as sm
import pandas as pd
from sqlalchemy import create_engine
import statsmodels.formula.api as smf
import numpy as np
from statsmodels.compat import lzip

import statsmodels.stats.api as sms
import matplotlib.pyplot as plt

engine = create_engine(r'postgresql+psycopg2://postgres:stats170@104.197.51.5')

# %%
df = pd.read_sql_query("""
select *
from yelp_data.shop_static_info;
""", con = engine)

df2 = pd.read_sql_query('''
Select *
from yelp_data.yelp_yolo
''', con = engine)
df3 = pd.read_sql_query('''
select *
from yelp_data.yelp_vertorize
''', con=engine)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-236-44fe83b6d6c1> in <module>
#       8 from yelp_data.yelp_yolo
#       9 ''', con = engine)
# ---> 10 df3 = pd.read_sql_query('''
#      11 select *
#      12 from yelp_data.yelp_vertorize
#
# D:\Anaconda\lib\site-packages\pandas\io\sql.py in read_sql_query(sql, con, index_col, coerce_float, params, parse_dates, chunksize, dtype)
#     397     """
#     398     pandas_sql = pandasSQL_builder(con)
# --> 399     return pandas_sql.read_query(
#     400         sql,
#     401         index_col=index_col,
#
# D:\Anaconda\lib\site-packages\pandas\io\sql.py in read_query(self, sql, index_col, coerce_float, parse_dates, params, chunksize, dtype)
#    1569             )
#    1570         else:
# -> 1571             data = result.fetchall()
#    1572             frame = _wrap_result(
#    1573                 data,
#
# ...

# %%
df3['vertorize_review'] = [i[1:-1].split(',') for i in df3['vertorize_review'].tolist()]
for i in range(100):
    df3[f'v_{i}'] = [float(j[i]) for j in df3['vertorize_review']]
# Out:
# <ipython-input-202-db276f894734>:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df3[f'v_{i}'] = [float(j[i]) for j in df3['vertorize_review']]
# <ipython-input-202-db276f894734>:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df3[f'v_{i}'] = [float(j[i]) for j in df3['vertorize_review']]

# %%
df3
# Out:
#                    business_id               review_id  \
# 0       o1bd3WLl4McflqjDTJTdHQ  BOL3hGWiZpzay3FcghAVww
# 1       Zx7n8mdt8OzLRXVzolXNhQ  E9AB7V4z8xrt2uPF7T55FQ
# 2       EQ-TZ2eeD_E0BHuvoaeG5Q  l3Wk_mvAog6XANIuGQ9C7Q
# 3       EQ-TZ2eeD_E0BHuvoaeG5Q  S-H-Ao17MEYH9cLpvevbnQ
# 4       hNH1ILskk1qu7TA0rBvvlw  3dpZV03faf7YynNxwCKlcA
# ...                        ...                     ...
# 442311  M5eciMJjAiEmwI_TUWrU1w  QMoYcuDczAHekUxz0O0F8g
# 442312  Ddg-J_j0YFErk7wpMtH_0A  OrYpmKDqmc3X7g7STa3jww
# 442313  h71Bxbv009IEmwsMzdWZ5A  dijqvaN-OmoztzJjqo40HQ
# 442314  a3p47WxYVo0BZGJoP1O0qA  34sCCOifL_zJez9nLjSZYQ
# 442315  a3p47WxYVo0BZGJoP1O0qA  d_h6-_FPRUcGwAUsPmVaew
#
#                                          vertorize_review       v_0       v_1  \
# 0       [0.19054149981678986, -0.5346833256686606, 0.4...  0.190541 -0.534683
# 1       [0.8214012291282415, -0.6675133653916419, 0.50...  0.821401 -0.667513
# ...

# %%
df3 = df3.groupby('business_id').mean()
df = df.merge(df2.groupby('photo_id').sum(),left_on='business_id',right_index=True)
df = df.merge(df3, on = 'business_id')

# %%
X = df[['rate_user_num',
 'state',
 'latitude',
 'longitude',
 'price_level',
 'HasTV',
 'Caters',
 'OutdoorSeating',
 'WheelchairAccessible',
 'BusinessParking',
 'RestaurantsDelivery',
 'GoodForKids',
 'BikeParking',
 'WiFi',
 'Alcohol',
 'RestaurantsTakeOut',
 'BusinessAcceptsCreditCards',
 'open_days',
 'open_hours',
 'num_rating',
 'drink',
 'food',
 'inside',
 'menu',
 'outside',
 'total',
 'avg_review_useful',
 'avg_review_funny',
 'avg_review_cool',
 'avg_stars',
 'avg_review_count',
 'avg_useful',
 'avg_funny',
 'avg_cool',
 'avg_fans',
 'avg_compliment_hot',
 'avg_compliment_more',
 'avg_compliment_profile',
 'avg_compliment_cute',
 'avg_compliment_list',
 'avg_compliment_note',
 'avg_compliment_plain',
 'avg_compliment_cool',
 'avg_compliment_funny',
 'avg_compliment_writer',
 'avg_compliment_photos',
 'yelp_years',
 'avg_total_compliment',
 'Total:_Estimate',
 '    Less than $20,000_Estimate',
 '    $20,000 to $39,999_Estimate',
 '    $40,000 to $59,999_Estimate',
 '    $60,000 to $99,999_Estimate',
 '    $100,000 to $149,999_Estimate',
 '    $150,000 to $199,999_Estimate',
 '    $200,000 or more_Estimate',
 'PAYANN',
 'PCHDAPR',
 'PCHADVT',
 'DENSITY_2021',
 'POP_2021',
 'Total:_Estimate_max',
 '    Less than $20,000_Estimate_max',
 '    $20,000 to $39,999_Estimate_max',
 '    $40,000 to $59,999_Estimate_max',
 '    $60,000 to $99,999_Estimate_max',
 '    $100,000 to $149,999_Estimate_max',
 '    $150,000 to $199,999_Estimate_max',
 '    $200,000 or more_Estimate_max',
 'Total:_Estimate_min',
 '    Less than $20,000_Estimate_min',
 '    $20,000 to $39,999_Estimate_min',
 '    $40,000 to $59,999_Estimate_min',
 '    $60,000 to $99,999_Estimate_min',
 '    $100,000 to $149,999_Estimate_min',
 '    $150,000 to $199,999_Estimate_min',
 '    $200,000 or more_Estimate_min',
 'less_100m',
 'less_500m',
 'less_1km',
 'less_5km',
 'less_10km',
 'less_50km']+[f'v_{i}'for i in range(100)]] 
y = df[ 'weighted_rating']

# %%
X['yelp_years'] = X['yelp_years'] / np.timedelta64(1, 'Y')
for i in X.columns:
    if X[i].dtype == np.object:
        X[i] = pd.factorize(X[i])[0]
# Out:
# <ipython-input-212-38217b7a6beb>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['yelp_years'] = X['yelp_years'] / np.timedelta64(1, 'Y')
# <ipython-input-212-38217b7a6beb>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X[i] = pd.factorize(X[i])[0]

# %%
X.replace([np.inf, -np.inf], 0, inplace=True)
X.replace(np.nan, 0, inplace=True)
# Out:
# <ipython-input-213-c925cddfbb59>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X.replace([np.inf, -np.inf], 0, inplace=True)
# <ipython-input-213-c925cddfbb59>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X.replace(np.nan, 0, inplace=True)

# %%
## fit a OLS model with intercept
X = sm.add_constant(X)
est = sm.OLS(y,X,missing='drop').fit()
est.summary()
# Out:
# D:\Anaconda\lib\site-packages\statsmodels\tsa\tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only.
#   x = pd.concat(x[::order], 1)
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:        weighted_rating   R-squared:                       0.690
# Model:                            OLS   Adj. R-squared:                  0.677
# Method:                 Least Squares   F-statistic:                     52.51
# Date:                Mon, 09 May 2022   Prob (F-statistic):               0.00
# Time:                        02:58:38   Log-Likelihood:                -183.29
# No. Observations:                3986   AIC:                             692.6
# Df Residuals:                    3823   BIC:                             1718.
# Df Model:                         162
# Covariance Type:            nonrobust
# ...

# %%
XT=X[['price_level','HasTV','OutdoorSeating','BusinessParking','GoodForKids','less_100m','yelp_years','avg_fans','avg_cool','avg_funny','avg_useful','avg_review_count','avg_stars','avg_review_cool','avg_review_funny','avg_review_useful','num_rating','open_hours','open_days','BusinessAcceptsCreditCards','RestaurantsTakeOut','less_5km','less_50km']]
est2 = sm.OLS(y,XT,missing='drop').fit()
est2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:        weighted_rating   R-squared (uncentered):                   0.994
# Model:                            OLS   Adj. R-squared (uncentered):              0.994
# Method:                 Least Squares   F-statistic:                          2.822e+04
# Date:                Mon, 09 May 2022   Prob (F-statistic):                        0.00
# Time:                        02:58:46   Log-Likelihood:                         -1236.6
# No. Observations:                3986   AIC:                                      2519.
# Df Residuals:                    3963   BIC:                                      2664.
# Df Model:                          23
# Covariance Type:            nonrobust
# ...
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ...

# %%
"""weighted_rating ~ rate_user_num +\
 as.factor(state)+\
 latitude+\
 longitude+\
 price_level+\
 HasTV+\
 Caters+\
 OutdoorSeating+\
 WheelchairAccessible+\
 BusinessParking+\
 RestaurantsDelivery+\
 GoodForKids+\
 BikeParking+\
 WiFi+\
 Alcohol+\
 RestaurantsTakeOut+\
 BusinessAcceptsCreditCards+\
 open_days+\
 open_hours+\
 num_rating+\
 drink+\
 food+\
 inside+\
 menu+\
 outside+\
 total+\
 avg_review_useful+\
 avg_review_funny+\
 avg_review_cool+\
 avg_stars+\
 avg_review_count+\
 avg_useful+\
 avg_funny+\
 avg_cool+\
 avg_fans+\
 avg_compliment_hot+\
 avg_compliment_more+\
 avg_compliment_profile+\
 avg_compliment_cute+\
 avg_compliment_list+\
 avg_compliment_note+\
 avg_compliment_plain+\
 avg_compliment_cool+\
 avg_compliment_funny+\
 avg_compliment_writer+\
 avg_compliment_photos+\
 yelp_years+\
 avg_total_compliment+\
 Total:_Estimate+\
 `    Less than $20,000_Estimate`+\
 `    $20,000 to $39,999_Estimate`+\
 `    $40,000 to $59,999_Estimate`+\
 `    $60,000 to $99,999_Estimate`+\
 `    $100,000 to $149,999_Estimate`+\
 `    $150,000 to $199,999_Estimate`+\
 `    $200,000 or more_Estimate`+\
 PAYANN+\
 PCHDAPR+\
 PCHADVT+\
 DENSITY_2021+\
 POP_2021+\
 Total:_Estimate_max+\
 `    Less than $20,000_Estimate_max`+\
 `    $20,000 to $39,999_Estimate_max`+\
 `    $40,000 to $59,999_Estimate_max`+\
 `    $60,000 to $99,999_Estimate_max`+\
 `    $100,000 to $149,999_Estimate_max`+\
 `    $150,000 to $199,999_Estimate_max`+\
 `    $200,000 or more_Estimate_max`+\
 Total:_Estimate_min+\
 `    Less than $20,000_Estimate_min`+\
 `    $20,000 to $39,999_Estimate_min` +\
 `    $40,000 to $59,999_Estimate_min` +\
 `    $60,000 to $99,999_Estimate_min` +\
 `    $100,000 to $149,999_Estimate_min` +\
 `    $150,000 to $199,999_Estimate_min` +\
 `    $200,000 or more_Estimate_min` +\
 less_100m +\
 less_500m +\
 less_1km +\
 less_5km +\
 less_10km +\
 less_50km"""

# %% [markdown]
# # Normality of the residuals
# ## Jarque-Bera test:

# %%
name = ["Jarque-Bera", "Chi^2 two-tail prob.", "Skew", "Kurtosis"]
test = sms.jarque_bera(est.resid)
lzip(name, test)
# Out:
# [('Jarque-Bera', 2819.981790708305),
#  ('Chi^2 two-tail prob.', 0.0),
#  ('Skew', -0.7536911605857477),
#  ('Kurtosis', 6.834985905622631)]

# %% [markdown]
# ## Omni test:

# %%
name = ["Chi^2", "Two-tail probability"]
test = sms.omni_normtest(est.resid)
lzip(name, test)
# Out:
# [('Chi^2', 661.0049772193881),
#  ('Two-tail probability', 2.9146938292783643e-144)]

# %% [markdown]
# # Influence tests

# %%
from statsmodels.graphics.regressionplots import plot_leverage_resid2

fig, ax = plt.subplots(figsize=(8, 6))
fig = plot_leverage_resid2(est, ax=ax)

# %% [markdown]
# # Multicollinearity
# ## Breush-Pagan test:

# %%
name = ["Lagrange multiplier statistic", "p-value", "f-value", "f p-value"]
test = sms.het_breuschpagan(est.resid, est.model.exog)
lzip(name, test)
# Out:
# [('Lagrange multiplier statistic', 838.649816508385),
#  ('p-value', 3.678802646725447e-163),
#  ('f-value', 45.91259353531347),
#  ('f p-value', 1.4800558390190339e-183)]

# %% [markdown]
# # Linearity
# ### Harvey-Collier multiplier test for Null hypothesis that the linear specification is correct:

# %%
name = ["t value", "p value"]
test = sms.linear_harvey_collier(est)
lzip(name, test)
# Out:
# [('t value', nan), ('p value', nan)]

# %%
import seaborn as sns
import scipy.stats as stats
sns.distplot(a= (y-est.predict(X)) ,bins = 15, fit=stats.norm,norm_hist=True,
            hist_kws = {'color':'steelblue','edgecolor':'black'},
            kde_kws = {'color':'black','linestyle':'--','label':'kernal density'},
            fit_kws = {'color':'red','linestyle':':','label':'normal distribution'}).set(title='Normality of error terms/residuals')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-268-fdced789a991> in <module>
#       1 import seaborn as sns
#       2 import scipy.stats as stats
# ----> 3 sns.distplot(a= (y-est2.predict(X)) ,bins = 15, fit=stats.norm,norm_hist=True,
#       4             hist_kws = {'color':'steelblue','edgecolor':'black'},
#       5             kde_kws = {'color':'black','linestyle':'--','label':'kernal density'},
#
# D:\Anaconda\lib\site-packages\statsmodels\base\model.py in predict(self, exog, transform, *args, **kwargs)
#    1097             exog = np.atleast_2d(exog)  # needed in count model shape[1]
#    1098
# -> 1099         predict_results = self.model.predict(self.params, exog, *args,
#    1100                                              **kwargs)
#    1101
#
# D:\Anaconda\lib\site-packages\statsmodels\regression\linear_model.py in predict(self, params, exog)
# ...

# %%
p = sns.scatterplot(est.predict(X),(y-est.predict(X)))
plt.xlabel('y_pred/predicted values')
plt.ylabel('Residuals')
plt.ylim(-10,10)
plt.xlim(0,6)
p = sns.lineplot([0,26],[0,0],color='blue')
p = plt.title('Residuals vs fitted values plot for homoscedasticity check')
# Out:
# D:\Anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# D:\Anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
residuals = y-est.predict(X)
mean_residuals = np.mean(residuals)
print("Mean of Residuals {}".format(mean_residuals))
# Out:
# Mean of Residuals 3.590173027017886e-11

# %%
# Goldfeld Quandt Test
import statsmodels.stats.api as sms
from statsmodels.compat import lzip
name = ['F statistic', 'p-value']
test = sms.het_goldfeldquandt(residuals, X)
lzip(name, test)
# Out:
# [('F statistic', 1.1747905278825257), ('p-value', 0.0002868415183637902)]

# %%
y_pred = est.predict(X)
plt.figure(figsize=(10,5))
p = sns.lineplot(y_pred,residuals,marker='o',color='blue')
plt.xlabel('y_pred/predicted values')
plt.ylabel('Residuals')
plt.ylim(-10,10)
plt.xlim(0,7)
p = sns.lineplot([0,26],[0,0],color='red')
p = plt.title('Residuals vs fitted values plot for autocorrelation check')
# Out:
# D:\Anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# D:\Anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
